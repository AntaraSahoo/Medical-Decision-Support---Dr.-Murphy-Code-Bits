# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#loadng the datset
dataset = pd.read_csv("heart_failure_clinical_records_dataset.csv")
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
dataset.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
#splitting the set 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)
print(type(X_train))
print(type(y_train))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
#normalizing values
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
dataset.shape
# Out:
# (299, 13)

# %%
#Random Forest Classification Algorithm
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 500, 
                                    criterion = 'gini', 
                                    random_state = 0,
                                    max_depth=30)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=30, n_estimators=500, random_state=0)

# %%
# predicting the test result
y_pred = classifier.predict(X_test)

# %%
#accuracy score and confusion matrix
from sklearn.metrics import confusion_matrix, accuracy_score
am = accuracy_score(y_test, y_pred)
print("Accuracy_Score: ",am)
cm = confusion_matrix(y_test, y_pred)
print(cm)

from sklearn.metrics import confusion_matrix,classification_report
print(classification_report(y_test,y_pred))
# Out:
# Accuracy_Score:  0.9333333333333333
# [[45  1]
#  [ 3 11]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96        46
#            1       0.92      0.79      0.85        14
#
#     accuracy                           0.93        60
#    macro avg       0.93      0.88      0.90        60
# weighted avg       0.93      0.93      0.93        60

# %%
#predicting a test result
c = classifier.predict(sc.transform([[75.0,0,582,0,20,1,265000.00,1.9,130,1,0,4]]))
print(c)
# Out:
# [1]

# %%
# predicting a test result
c = classifier.predict(sc.transform([[49,1,80,0,30,1,427000,1,138,0,0,12]]))
print(c)
# Out:
# [0]
