# %%
import tensorflow
import matplotlib.pyplot as plt 
import numpy as np

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255,
                                 zoom_range = 0.2,
                                 vertical_flip = True,
                                 horizontal_flip = True)

training_set = train_datagen.flow_from_directory("C://Users//KIIT//Desktop//minor project//datasets//lungs_pneumonia//train",
                                                target_size = (64,64),
                                                class_mode = 'sparse')

test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = test_datagen.flow_from_directory("C://Users//KIIT//Desktop//minor project//datasets//lungs_pneumonia//test",
                                                target_size = (64,64),
                                                            class_mode = 'sparse')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
#test_image = "C://Users//KIIT//Desktop//0b8dabb7-5f1b-4fdc-b3fa-30b289707b90___JR_FrgE.S 3047_90deg.JPG"
#test_image = np.array((test_image))
#plt.imshow(test_image[0])

# %%
classifier = Sequential()

#first dense layer
classifier.add(Conv2D(filters = 32, kernel_size = (3, 3), input_shape = [64, 64, 3], activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2), strides = 2)) 

#second dense layer
classifier.add(Conv2D(filters = 32, kernel_size = (3, 3), input_shape = [64, 64, 3], activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2), strides = 2)) 
classifier.add(Flatten())

# %%
classifier.add(Dense(units = 128, activation = 'relu'))
classifier.add(Dense(units = 32, activation = 'relu'))
classifier.add(Dense(units = 16, activation = 'relu'))
classifier.add(Dense(units = 4, activation = 'softmax')) #put entire data into probablity
classifier.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['sparse_categorical_accuracy']) # compiling = stochastic gradient

# %%
classifier.fit_generator(training_set,
                         epochs = 25, 
                         validation_data = test_set)
# Out:
# C:\Users\KIIT\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/25
# 163/163 [==============================] - 152s 926ms/step - loss: 0.6221 - sparse_categorical_accuracy: 0.7240 - val_loss: 0.4267 - val_sparse_categorical_accuracy: 0.8029
# Epoch 2/25
# 163/163 [==============================] - 152s 930ms/step - loss: 0.2901 - sparse_categorical_accuracy: 0.8788 - val_loss: 0.3600 - val_sparse_categorical_accuracy: 0.8413
# Epoch 3/25
# 163/163 [==============================] - 143s 878ms/step - loss: 0.2539 - sparse_categorical_accuracy: 0.8910 - val_loss: 0.3160 - val_sparse_categorical_accuracy: 0.8750
# Epoch 4/25
# 163/163 [==============================] - 168s 1s/step - loss: 0.2160 - sparse_categorical_accuracy: 0.9072 - val_loss: 0.3650 - val_sparse_categorical_accuracy: 0.8670
# Epoch 5/25
# 163/163 [==============================] - 179s 1s/step - loss: 0.2092 - sparse_categorical_accuracy: 0.9094 - val_loss: 0.5924 - val_sparse_categorical_accuracy: 0.7660
# Epoch 6/25
# 163/163 [==============================] - 175s 1s/step - loss: 0.1981 - sparse_categorical_accuracy: 0.9180 - val_loss: 0.2789 - val_sparse_categorical_accuracy: 0.8926
# Epoch 7/25
# 163/163 [==============================] - 188s 1s/step - loss: 0.1920 - sparse_categorical_accuracy: 0.9203 - val_loss: 0.2639 - val_sparse_categorical_accuracy: 0.8926
# Epoch 8/25
# 163/163 [==============================] - 237s 1s/step - loss: 0.1952 - sparse_categorical_accuracy: 0.9207 - val_loss: 0.3738 - val_sparse_categorical_accuracy: 0.8590
# Epoch 9/25
# 163/163 [==============================] - 261s 2s/step - loss: 0.1796 - sparse_categorical_accuracy: 0.9277 - val_loss: 0.2897 - val_sparse_categorical_accuracy: 0.8894
# Epoch 10/25
# 163/163 [==============================] - 263s 2s/step - loss: 0.1665 - sparse_categorical_accuracy: 0.9388 - val_loss: 0.2805 - val_sparse_categorical_accuracy: 0.9006
# Epoch 11/25
# 163/163 [==============================] - 261s 2s/step - loss: 0.1561 - sparse_categorical_accuracy: 0.9321 - val_loss: 0.2717 - val_sparse_categorical_accuracy: 0.8958
# Epoch 12/25
# 163/163 [==============================] - 259s 2s/step - loss: 0.1574 - sparse_categorical_accuracy: 0.9423 - val_loss: 0.3075 - val_sparse_categorical_accuracy: 0.8910
# Epoch 13/25
# 163/163 [==============================] - 2871s 18s/step - loss: 0.1721 - sparse_categorical_accuracy: 0.9335 - val_loss: 0.2960 - val_sparse_categorical_accuracy: 0.8830
# Epoch 14/25
# 163/163 [==============================] - 286s 2s/step - loss: 0.1552 - sparse_categorical_accuracy: 0.9361 - val_loss: 0.8523 - val_sparse_categorical_accuracy: 0.7628
# Epoch 15/25
# 163/163 [==============================] - 263s 2s/step - loss: 0.1459 - sparse_categorical_accuracy: 0.9379 - val_loss: 0.4610 - val_sparse_categorical_accuracy: 0.8718
# Epoch 16/25
# 163/163 [==============================] - 167s 1s/step - loss: 0.1613 - sparse_categorical_accuracy: 0.9376 - val_loss: 0.5229 - val_sparse_categorical_accuracy: 0.8782
# Epoch 17/25
# 163/163 [==============================] - 172s 1s/step - loss: 0.1456 - sparse_categorical_accuracy: 0.9475 - val_loss: 0.3526 - val_sparse_categorical_accuracy: 0.8862
# Epoch 18/25
# 163/163 [==============================] - 168s 1s/step - loss: 0.1370 - sparse_categorical_accuracy: 0.9439 - val_loss: 0.5683 - val_sparse_categorical_accuracy: 0.8317
# Epoch 19/25
# 163/163 [==============================] - 165s 1s/step - loss: 0.1451 - sparse_categorical_accuracy: 0.9475 - val_loss: 0.2517 - val_sparse_categorical_accuracy: 0.9006
# Epoch 20/25
# 163/163 [==============================] - 163s 1s/step - loss: 0.1507 - sparse_categorical_accuracy: 0.9455 - val_loss: 0.4299 - val_sparse_categorical_accuracy: 0.8542
# Epoch 21/25
# 163/163 [==============================] - 172s 1s/step - loss: 0.1432 - sparse_categorical_accuracy: 0.9433 - val_loss: 0.3313 - val_sparse_categorical_accuracy: 0.8942
# Epoch 22/25
# 163/163 [==============================] - 183s 1s/step - loss: 0.1434 - sparse_categorical_accuracy: 0.9480 - val_loss: 0.3235 - val_sparse_categorical_accuracy: 0.8958
# Epoch 23/25
# 163/163 [==============================] - 159s 975ms/step - loss: 0.1297 - sparse_categorical_accuracy: 0.9546 - val_loss: 0.2679 - val_sparse_categorical_accuracy: 0.9038
# Epoch 24/25
# 163/163 [==============================] - 164s 1s/step - loss: 0.1308 - sparse_categorical_accuracy: 0.9496 - val_loss: 0.4884 - val_sparse_categorical_accuracy: 0.8526
# Epoch 25/25
# 163/163 [==============================] - 157s 960ms/step - loss: 0.1369 - sparse_categorical_accuracy: 0.9481 - val_loss: 0.5594 - val_sparse_categorical_accuracy: 0.8253

# %%
print(classifier.loss[0])
# Out:
# s

# %%
import numpy as np #coz. we convert image data into array
from tensorflow.keras.preprocessing import image

test_image = image.load_img("C://Users//KIIT//Desktop//person1946_bacteria_4874.jpeg", target_size = (64,64))
test_image = image.img_to_array(test_image) #after loading the data, we convert it into array
test_image = np.expand_dims(test_image, axis = 0) #expand dimensions around x axis
test_image = test_image/255
result = classifier.predict_classes(test_image)

print(training_set.class_indices)

if result == 0:
    print("Disease is : none")
if result == 1:
    print("Pneumonia Pertains")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-280683f4abef> in <module>
#       2 from tensorflow.keras.preprocessing import image
#       3
# ----> 4 test_image = image.load_img("C://Users//KIIT//Desktop//person1946_bacteria_4874.jpeg", target_size = (64,64))
#       5 test_image = image.img_to_array(test_image) #after loading the data, we convert it into array
#       6 test_image = np.expand_dims(test_image, axis = 0) #expand dimensions around x axis
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\preprocessing\image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     298   """
#     299   return image.load_img(path, grayscale=grayscale, color_mode=color_mode,
# --> 300                         target_size=target_size, interpolation=interpolation)
#     301
#     302
#
# ~\Anaconda3\lib\site-packages\keras_preprocessing\image\utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     111         raise ImportError('Could not import PIL.Image. '
#     112                           'The use of `load_img` requires PIL.')
# --> 113     with open(path, 'rb') as f:
#     114         img = pil_image.open(io.BytesIO(f.read()))
#     115         if color_mode == 'grayscale':
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C://Users//KIIT//Desktop//person1946_bacteria_4874.jpeg'

# %%
import numpy as np #coz. we convert image data into array
from tensorflow.keras.preprocessing import image

test_image = image.load_img("C://Users//KIIT//Desktop//person1946_bacteria_4874.jpeg", target_size = (64,64))
test_image = image.img_to_array(test_image) #after loading the data, we convert it into array
test_image = np.expand_dims(test_image, axis = 0) #expand dimensions around x axis
test_image = test_image/255
result = classifier.predict_classes(test_image)

print(training_set.class_indices)

if result == 0:
    print("Disease is : Apple_scab")
if result == 1:
    print("Disease is : Black_rot")
if result == 2:
    print("Disease is : Apple_rust")
if result == 3:
    print("It's Healthy")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-3be2db6cf299> in <module>
#       2 from tensorflow.keras.preprocessing import image
#       3
# ----> 4 test_image = image.load_img("C://Users//KIIT//Desktop//person1946_bacteria_4874.jpeg", target_size = (64,64))
#       5 test_image = image.img_to_array(test_image) #after loading the data, we convert it into array
#       6 test_image = np.expand_dims(test_image, axis = 0) #expand dimensions around x axis
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\preprocessing\image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     298   """
#     299   return image.load_img(path, grayscale=grayscale, color_mode=color_mode,
# --> 300                         target_size=target_size, interpolation=interpolation)
#     301
#     302
#
# ~\Anaconda3\lib\site-packages\keras_preprocessing\image\utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     111         raise ImportError('Could not import PIL.Image. '
#     112                           'The use of `load_img` requires PIL.')
# --> 113     with open(path, 'rb') as f:
#     114         img = pil_image.open(io.BytesIO(f.read()))
#     115         if color_mode == 'grayscale':
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C://Users//KIIT//Desktop//person1946_bacteria_4874.jpeg'

# %%
import numpy as np #coz. we convert image data into array
from tensorflow.keras.preprocessing import image

test_image = image.load_img("C://Users//KIIT//Desktop//agriculture project//Apple_test//Apple___healthy//0c55b379-c6e7-4b89-959f-abc506fed437___RS_HL 5927.JPG", target_size = (64,64))
test_image = image.img_to_array(test_image) #after loading the data, we convert it into array
test_image = np.expand_dims(test_image, axis = 0) #expand dimensions around x axis
test_image = test_image/255
result = classifier.predict_classes(test_image)

print(training_set.class_indices)

if result == 0:
    print("Disease is : Apple_scab")
if result == 1:
    print("Disease is : Black_rot")
if result == 2:
    print("Disease is : Apple_rust")
if result == 3:
    print("It's Healthy")
# Out:
# C:\Users\KIIT\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# {'NORMAL': 0, 'PNEUMONIA': 1}
# Disease is : Black_rot
