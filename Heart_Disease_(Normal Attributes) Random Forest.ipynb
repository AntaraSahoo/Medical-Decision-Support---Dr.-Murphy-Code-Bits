# %%
#import libraries
import pandas as pd
import numpy as np
import pickle

# %%
#loadng the datset
dataset = pd.read_csv("cardio_train.csv", sep = ";")
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values
dataset.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
#splitting the set 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 3)
print(type(X_train))
print(type(y_train))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
#normalizing values
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X.shape
# Out:
# (70000, 11)

# %%
#Random Forest Classification Algorithm
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 50, 
                                    criterion = 'gini', 
                                    random_state = 3,
                                    max_depth=5)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=5, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=50,
#                        n_jobs=None, oob_score=False, random_state=3, verbose=0,
#                        warm_start=False)

# %%
# predicting the test result
y_pred = classifier.predict(X_test)

# %%
#accuracy score and confusion matrix
from sklearn.metrics import confusion_matrix, accuracy_score
am = accuracy_score(y_test, y_pred)
print("Accuracy_Score: ",am)
cm = confusion_matrix(y_test, y_pred)
print(cm)

from sklearn.metrics import confusion_matrix,classification_report
print(classification_report(y_test,y_pred))
# Out:
# Accuracy_Score:  0.7265714285714285
# [[5544 1533]
#  [2295 4628]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.78      0.74      7077
#            1       0.75      0.67      0.71      6923
#
#     accuracy                           0.73     14000
#    macro avg       0.73      0.73      0.73     14000
# weighted avg       0.73      0.73      0.73     14000

# %%
pickle.dump(classifier, open('model_1.pkl','wb'))
#Loading model to compare the results
model_1 = pickle.load(open('model_1.pkl','rb'))

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X_train,y_train)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
# Out:
# C:\Users\KIIT\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [0.28540299 0.00422839 0.16952718 0.17578962 0.18141244 0.10974109
#  0.04796991 0.01320766 0.00412638 0.00421701 0.00437734]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-06a2ae21756b> in <module>
#       6
#       7 #plotting graph of feature importances for better visualization
# ----> 8 feat_importances = pd.Series(model.feature_importances_, index=dataset.columns)
#       9 feat_importances.nlargest(11).plot(kind='barh')
#      10 plt.show()
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     297                         raise ValueError(
# ...

# %%
import requests
url = 'http://localhost:5000/heart_normal'
r = requests.post(url,json={'a':'20228','b':"1",'c':"156",'d':"85",'e':"140",'f':"90",'g':"3",'h':"1",'i':"0",'j':"0",'k':"1"})
print(r.json())
