# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("exasens.csv")
dataset.dropna(inplace = True)
dataset.isnull().sum()
dataset
# Out:
#     Diagnosis     ID  Imagery_part_min  Imagery_part_avg  Real_part_min  \
# 0        COPD  301-4           -320.61       -300.563531        -495.26
# 1        COPD  302-3           -325.39       -314.750360        -473.73
# 2        COPD  303-3           -323.00       -317.436056        -476.12
# 3        COPD  304-4           -327.78       -317.399670        -473.73
# 4        COPD  305-4           -325.39       -316.155785        -478.52
# ..        ...    ...               ...               ...            ...
# 366  Infected  148-5           -323.00       -314.384434        -476.12
# 367  Infected  149-5           -323.00       -314.323628        -476.12
# 368  Infected  150-5           -323.00       -312.856656        -480.91
# 369  Infected  151-4           -327.78       -319.305447        -476.12
# 375  Infected  157-3           -327.78       -318.068499        -473.73
#
#      Real_part_avg  Gender  Age  Smoking
# 0      -464.171991       1   77        2
# 1      -469.263140       0   72        2
# 2      -471.897667       1   73        3
# 3      -468.856388       1   76        2
# 4      -472.869783       0   65        2
# ..             ...     ...  ...      ...
# 366    -472.103689       1   38        1
# 367    -472.395413       1   36        1
# 368    -472.294281       0   33        1
# 369    -471.776918       1   43        1
# 375    -457.046464       0   25        2
#
# [100 rows x 9 columns]

# %%
X = dataset.iloc[:,2:8].values
y = dataset.iloc[:,0].values

# %%
dataset.shape
# Out:
# (100, 9)

# %%
dataset.dtypes
# Out:
# Diagnosis            object
# ID                   object
# Imagery_part_min    float64
# Imagery_part_avg    float64
# Real_part_min       float64
# Real_part_avg       float64
# Gender                int64
# Age                   int64
# Smoking               int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 2)
print(type(X_train))
print(type(y_train))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
print(X_train)
# Out:
# [[-332.57      -319.0374144 -473.73      -463.2120865    0.
#     54.       ]
#  [-315.82      -294.2698616 -471.34      -463.1934272    0.
#     56.       ]
#  [-320.61      -311.658041  -473.73      -469.729237     0.
#     76.       ]
#  [-320.61      -302.6182807 -468.95      -464.8477558    0.
#     21.       ]
#  [-327.78      -318.792207  -478.52      -473.7268171    1.
#     18.       ]
#  [-327.78      -318.6775535 -507.23      -469.0241943    1.
#     60.       ]
#  [-231.        -231.        -441.        -441.           1.
#     73.       ]
#  [-330.18      -320.9939204 -466.55      -459.6267977    1.
#     18.       ]
#  [-337.35      -328.2809854 -500.05      -466.9809668    1.
#     20.       ]
#  [-323.        -313.0565374 -473.73      -468.5672198    1.
#     27.       ]
#  [-320.61      -311.8019294 -500.05      -468.0027422    1.
#     46.       ]
#  [-325.39      -314.7503595 -473.73      -469.2631404    0.
#     72.       ]
#  [-228.        -228.        -442.        -442.           1.
#     75.       ]
#  [-323.        -314.4867067 -468.95      -465.5598299    0.
#     23.       ]
#  [-330.18      -321.0494384 -468.95      -463.7133737    1.
#     66.       ]
#  [-330.18      -321.3858594 -476.12      -471.5781956    1.
#     34.       ]
#  [-330.18      -320.6174777 -473.73      -467.3618538    1.
#     76.       ]
#  [-327.78      -318.4467    -478.52      -470.9259266    0.
#     58.       ]
#  [-327.78      -319.5552854 -476.12      -472.8005812    0.
#     27.       ]
#  [-318.21      -306.2530384 -471.34      -466.5250462    1.
#     75.       ]
#  [-313.43      -299.0552022 -521.58      -421.1894102    1.
#     75.       ]
#  [-236.        -236.         -44.         -44.           0.
#     42.       ]
#  [-327.78      -315.5109894 -468.95      -464.1402657    0.
#     17.       ]
#  [-320.61      -303.846226  -502.44      -464.5463644    1.
#     31.       ]
#  [-323.        -314.3844336 -476.12      -472.1036892    1.
#     38.       ]
#  [-327.78      -319.1253683 -471.34      -464.8151111    1.
#     68.       ]
#  [-225.        -225.        -443.        -443.           1.
#     75.       ]
#  [-228.        -228.        -442.        -442.           1.
#     85.       ]
#  [-235.        -235.        -446.        -446.           0.
#     43.       ]
#  [-234.        -234.        -445.        -445.           0.
#     26.       ]
#  [-320.61      -308.117898  -471.34      -466.13057      1.
#     65.       ]
#  [-323.        -314.3236277 -476.12      -472.3954131    1.
#     36.       ]
#  [-323.        -314.5167598 -502.44      -467.7786275    1.
#     75.       ]
#  [-235.        -235.        -447.        -447.           1.
#     60.       ]
#  [-315.82      -304.8757423 -468.95      -461.0824463    1.
#     29.       ]
#  [-330.18      -297.8869521 -519.19      -473.9286981    1.
#     41.       ]
#  [-327.78      -318.8811995 -473.73      -470.9443434    0.
#     63.       ]
#  [-308.64      -284.134625  -550.29      -455.3339083    0.
#     58.       ]
#  [-323.        -312.8566556 -480.91      -472.2942809    0.
#     33.       ]
#  [-315.82      -300.104765  -473.73      -466.3786343    1.
#     67.       ]
#  [-325.39      -320.0732383 -476.12      -463.0258699    1.
#     28.       ]
#  [-320.61      -311.4236175 -478.52      -472.3070296    0.
#     50.       ]
#  [-320.61      -312.0769686 -476.12      -470.8114614    0.
#     28.       ]
#  [-327.78      -319.305447  -476.12      -471.7769183    1.
#     43.       ]
#  [-320.61      -312.0221071 -473.73      -469.5311905    0.
#     26.       ]
#  [-320.61      -311.9177803 -473.73      -469.1285945    1.
#     57.       ]
#  [-325.39      -316.7517489 -466.55      -458.4269978    0.
#     53.       ]
#  [-323.        -314.284076  -466.55      -462.1414882    0.
#     42.       ]
#  [-327.78      -317.6866106 -473.73      -467.977492     1.
#     64.       ]
#  [-320.61      -311.859266  -473.73      -470.8908275    0.
#     40.       ]
#  [-325.39      -316.2322014 -473.73      -469.5923529    1.
#     52.       ]
#  [-327.78      -318.5670948 -507.23      -469.5871885    1.
#     44.       ]
#  [-323.        -314.7600678 -473.73      -469.2765507    1.
#     25.       ]
#  [-330.18      -319.4005024 -476.12      -469.1655772    1.
#     52.       ]
#  [-327.78      -318.2295582 -471.34      -465.3020942    0.
#     46.       ]
#  [-236.        -236.        -448.        -448.           0.
#     23.       ]
#  [-327.78      -316.6045147 -473.73      -466.4463462    0.
#     71.       ]
#  [-323.        -314.4921486 -476.12      -471.737103     1.
#     77.       ]
#  [-323.        -314.8958957 -492.87      -467.8587217    0.
#     55.       ]
#  [-320.61      -305.9119073 -468.95      -465.4367023    0.
#     41.       ]
#  [-325.39      -316.1557853 -478.52      -472.8697828    0.
#     65.       ]
#  [-337.35      -325.6579503 -473.73      -463.6404025    1.
#     48.       ]
#  [-330.18      -320.9938889 -471.34      -467.1541667    1.
#     68.       ]
#  [-330.18      -317.9456057 -476.12      -464.9861141    1.
#     68.       ]
#  [-325.39      -315.61542   -471.34      -464.3431669    1.
#     69.       ]
#  [-330.18      -320.4808736 -476.12      -472.5830747    1.
#     77.       ]
#  [-318.21      -301.445923  -464.16      -410.0670714    1.
#     28.       ]
#  [-327.78      -320.7771624 -478.52      -471.2407847    0.
#     38.       ]
#  [-320.61      -312.0220043 -473.73      -467.1178382    0.
#     44.       ]
#  [-320.61      -311.6483437 -476.12      -472.2331573    1.
#     22.       ]
#  [-325.39      -317.351689  -471.34      -467.3918418    0.
#     39.       ]
#  [-327.78      -318.8434222 -476.12      -471.7648889    1.
#     71.       ]
#  [-320.61      -307.5995856 -476.12      -470.1816328    1.
#     74.       ]
#  [-323.        -312.116093  -468.95      -456.3999337    1.
#     19.       ]
#  [-320.61      -311.9077855 -471.34      -467.7552661    1.
#     53.       ]
#  [-320.61      -286.0521862 -626.86      -470.413137     1.
#     27.       ]
#  [-323.        -314.3307253 -468.95      -465.8307169    0.
#     49.       ]
#  [-337.35      -321.9222487 -507.23      -464.4679806    1.
#     52.       ]
#  [-308.64      -294.366142  -468.95      -414.6756675    1.
#     70.       ]
#  [-303.86      -288.0444774 -514.4       -453.2254697    0.
#     50.       ]]

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 200, 
                                    criterion = 'gini', 
                                    random_state = 3,
                                    max_depth=20)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=20, n_estimators=200, random_state=3)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
am = accuracy_score(y_test, y_pred)
print (am)
from sklearn.metrics import confusion_matrix,classification_report
print(classification_report(y_test,y_pred))
# Out:
# [[ 0  0  0  1]
#  [ 1 12  0  0]
#  [ 0  0  4  0]
#  [ 0  0  1  1]]
# 0.85
#               precision    recall  f1-score   support
#
#       Asthma       0.00      0.00      0.00         1
#         COPD       1.00      0.92      0.96        13
#           HC       0.80      1.00      0.89         4
#     Infected       0.50      0.50      0.50         2
#
#     accuracy                           0.85        20
#    macro avg       0.57      0.61      0.59        20
# weighted avg       0.86      0.85      0.85        20
