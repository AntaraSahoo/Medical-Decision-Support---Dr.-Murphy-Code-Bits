# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('Fertilizer Prediction.csv')
X=dataset.iloc[:,:1].values
Y=dataset.iloc[:,-1].values

# %%
#from sklearn.compose import ColumnTransformer
#from sklearn.preprocessing import OneHotEncoder
#ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[0])],remainder='passthrough')
#X=np.array(ct.fit_transform(X))

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
dataset['Soil Type'] = label_encoder.fit_transform(dataset['Soil Type'])
dataset['Soil Type'].unique()

from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
dataset['Soil Type'] = label_encoder.fit_transform(dataset['Soil Type'])
dataset['Soil Type'].unique()
# Out:
# array([4, 2, 0, 3, 1], dtype=int64)

# %%
#from sklearn import preprocessing
#label_encoder_crop=preprocessing.LabelEncoder()
#dataset['Crop Type']=label_encoder_crop.fit_transform(dataset['Crop Type'])
#dataset['Crop Type'].unique()

# %%
#X=np.asarray(X).astype('float32')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion='entropy', random_state= 1)
classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=1, splitter='best')

# %%
c = classifier.predict(sc.transform([[26,52,38,4.0,3.0,37,0,0]]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-f73c95653f3b> in <module>
# ----> 1 c = classifier.predict(sc.transform[[26,52,38,"Sandy","Maize",37,0,0]])
#
# TypeError: 'method' object is not subscriptable

# %%
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
am=accuracy_score(y_test,y_pred)
print(am)
